# %% [markdown]
# # Data load

# %%
import json
import numpy as np
import pandas as pd

review = pd.read_json('C:\dev\cosmo-hackers\glowpick.json', encoding = 'UTF-8')
user = pd.read_json('C:\dev\cosmo-hackers\glowpick_user_data.json', encoding = 'UTF-8')
product = pd.read_json('C:\dev\cosmo-hackers\glowpick_product_data.json', encoding = 'UTF-8')

# %%
review.head()
# Out:
#                                             contents          created_at  \
# 0  이거하얀색쓰는데 너무좋아요\n유리아쥬 저렴이같아요.\n바이오더마보다 꾸덕해요. 카멕... 2019-02-27 04:07:16
# 1  내 입술이 이상한건지 다른 립밤은 쓰면 더 각질부각이 되는데 이거는 갠차나여!! 촉... 2019-02-26 16:18:14
# 2  립밤 필요해서 한번 사봤는데 집에서 바르기 좋음. 유채향은 잘 모르겠는데 정말 꿀같... 2019-02-24 02:00:19
# 3  생일선물 받았었는데 진짜 촉촉하고 꿀 향도 너무 좋아서 재구매했던 기억이 ㅋㅋㅋㅋ ... 2019-02-12 11:36:55
# 4  두개를 샀는데 하나는 너무 주황에가까워서 안맞고  또 다른거는 뚜껑에 림밤이 붙어서... 2019-02-10 02:26:16
#
#    is_evaluation  like_count  product_id  rating  review_id state  user_id
# 0          False           0         142       5    4824477     N  1178442
# 1          False           1         142       4    4823753     N   953106
# 2          False           0         142       4    4814920     N  1214255
# 3          False           0         142       5    4788677     N  1201753
# 4          False           0         142       2    4781328     N  1194981

# %%
user.head()
# Out:
#     age  birth_year                  email gender  is_blinded    nickname  \
# 0  22.0      1998.0       ss2a53@naver.com      f           0     푸시아핑크악개
# 1  28.0      1992.0    se1004k@hanmail.net      f           0        이유커플
# 2  24.0      1996.0      osy0105@naver.com      f           0      레인0105
# 3  20.0      2000.0  younseo0917@naver.com      f           0  you_n_seo_
# 4  21.0      1999.0   wlsdud3566@naver.com      f           0        99진영
#
#                                        profile_image   rank  review_count  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...   5159           131
# 1  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...   6399           113
# 2  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  14150            57
# 3  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  11334            80
# 4                                               None  19020            57
#
#   skin_type  user_id
# 0        중성  1066725
# 1        건성  1120845
# ...

# %%
product.head()
# Out:
#                                                brand goods_info  \
# 0  {'brand_id': 11, 'name': 'VDL(브이디엘)', 'brand_i...       None
# 1  {'brand_id': 11, 'name': 'VDL(브이디엘)', 'brand_i...       None
# 2  {'brand_id': 11, 'name': 'VDL(브이디엘)', 'brand_i...       None
# 3  {'brand_id': 13, 'name': '겔랑', 'brand_image': ...       None
# 4  {'brand_id': 13, 'name': '겔랑', 'brand_image': ...       None
#
#                           name  product_id  \
# 0                     틴트바 트리플샷           4
# 1                    틴트바 밀크콜라다           5
# 2                      틴트바 젤티니           6
# 3  겔랑 루즈 G 드 세리 느와르 쥬얼 립스틱 컴팩트           7
# 4                     루즈 오토마띠끄           8
#
#                                        product_image
# 0  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 1  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 3  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# ...

# %% [markdown]
# # Data merge & cleaning

# %%
joinuser = review.merge(user)

# %%
joinuser.head()
# Out:
#                                             contents          created_at  \
# 0  이거하얀색쓰는데 너무좋아요\n유리아쥬 저렴이같아요.\n바이오더마보다 꾸덕해요. 카멕... 2019-02-27 04:07:16
# 1  내 입술이 이상한건지 다른 립밤은 쓰면 더 각질부각이 되는데 이거는 갠차나여!! 촉... 2019-02-26 16:18:14
# 2  립밤 필요해서 한번 사봤는데 집에서 바르기 좋음. 유채향은 잘 모르겠는데 정말 꿀같... 2019-02-24 02:00:19
# 3  부드럽게 잘 발려서 좋은 거 같고 가성비도 좋은편이에요 초보자들이 사용하기 좋은 제... 2019-02-27 04:29:46
# 4  초보자들한테 좋을듯 싶어요 제가 초보일때 이걸 사용해봤는데 쉽게 슥슥 그려지고 좋더라구요 2019-02-27 04:28:09
#
#    is_evaluation  like_count  product_id  rating  review_id state  user_id  \
# 0          False           0         142       5    4824477     N  1178442
# 1          False           1         142       4    4823753     N   953106
# 2          False           0         142       4    4814920     N  1214255
# 3          False           0        7077       4    4824512     N  1214255
# 4          False           0       93639       4    4824510     N  1214255
#
#     age  birth_year                email gender  is_blinded nickname  \
# ...

# %%
data = joinuser.drop(["contents", "like_count", "is_evaluation","email","nickname","profile_image", "is_blinded", ], 1)

# %%
data = data.merge(product)

# %%
def getBrand(brand):
    name = brand.get('name')
    return name

brand = list(dict(product['brand']).values())

brandname = list(map(getBrand, brand))

new = pd.DataFrame({'brandName':brandname, 'product_id': product['product_id']})

jointotal = data.merge(new)

# %%
jointotal.head()
# Out:
#            created_at  product_id  rating  review_id state  user_id   age  \
# 0 2019-02-27 04:07:16         142       5    4824477     N  1178442  26.0
# 1 2019-02-26 16:18:14         142       4    4823753     N   953106  28.0
# 2 2019-02-24 02:00:19         142       4    4814920     N  1214255  23.0
# 3 2019-02-12 11:36:55         142       5    4788677     N  1201753  25.0
# 4 2019-02-10 02:26:16         142       2    4781328     N  1194981  17.0
#
#    birth_year gender   rank  review_count skin_type  \
# 0      1994.0      f  54184            10        건성
# 1      1992.0      f  44450            23        건성
# 2      1997.0      f  52887            15       복합성
# 3      1995.0      f  47694            20       민감성
# 4      2003.0      f  51696            16       복합성
#
#                                                brand goods_info       name  \
# 0  {'brand_id': 186, 'name': '이니스프리(innisfree)', ...       None  유채꿀 립밤 스틱
# ...

# %%
data = jointotal.drop(["state", "brand","goods_info","birth_year", "product_image"], 1)

# %%
data.describe()
# Out:
#           product_id         rating     review_id       user_id  \
# count  149711.000000  149711.000000  1.497110e+05  1.497110e+05
# mean    28482.319850       3.675268  2.687582e+06  4.883882e+05
# std     32747.674331       1.088216  1.465477e+06  3.219544e+05
# min       142.000000       1.000000  1.500000e+01  3.000000e+00
# 25%      6866.000000       3.000000  1.485135e+06  1.250520e+05
# 50%      7100.000000       4.000000  3.024581e+06  5.728050e+05
# 75%     52845.000000       5.000000  3.869154e+06  7.137620e+05
# max     99874.000000       5.000000  4.824842e+06  1.216711e+06
#
#                  age          rank   review_count
# count  149710.000000  1.497110e+05  149711.000000
# mean       24.637766  2.033743e+04     106.084717
# std         5.481513  1.718961e+05     133.527918
# min         1.000000  1.000000e+00      -7.000000
# 25%        21.000000  3.942000e+03      38.000000
# 50%        24.000000  1.268800e+04      62.000000
# ...

# %% [markdown]
# # Load to Database

# %%
import json
import numpy as np
import pandas as pd
import sqlite3

con = sqlite3.connect("C:\\glowpickDB.db")

# %%
data.to_sql('innisfree', con, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-783f58821ffc> in <module>
# ----> 1 data.to_sql('innisfree', con, if_exists='replace')
#
# NameError: name 'data' is not defined

# %%
con.commit()

# %% [markdown]
# # Recommendation by suprise

# %%
import pandas as pd
import sqlite3
import surprise

con = sqlite3.connect("C:\\glowpickDB.db")

df = pd.read_sql("SELECT user_id, product_id, rating FROM innisfree", con)

userId=pd.to_numeric(df['user_id'])
productId=pd.to_numeric(df['product_id'])
rating=pd.to_numeric(df['rating'])

temp={"user":userId,'item':productId,'rating':rating}

df=pd.DataFrame(temp,columns = ['user', 'item','rating'])

# %%
df.shape
# Out:
# (149711, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149711 entries, 0 to 149710
# Data columns (total 3 columns):
# user      149711 non-null int64
# item      149711 non-null int64
# rating    149711 non-null int64
# dtypes: int64(3)
# memory usage: 3.4 MB

# %%
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)

data = df['rating'].value_counts().sort_index(ascending=False)
trace = go.Bar(x = data.index,
               text = ['{:.1f} %'.format(val) for val in (data.values / df.shape[0] * 100)],
               textposition = 'auto',
               textfont = dict(color = '#000000'),
               y = data.values,
               )

# Create layout
layout = dict(title = 'Distribution Of {} item-ratings'.format(df.shape[0]),
              xaxis = dict(title = 'Rating'),
              yaxis = dict(title = 'Count'))

# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-1a82d2ee0e66> in <module>
# ----> 1 from plotly.offline import init_notebook_mode, plot, iplot
#       2 import plotly.graph_objs as go
#       3 init_notebook_mode(connected=True)
#       4
#       5 data = df['rating'].value_counts().sort_index(ascending=False)
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Number of ratings per item
data = df.groupby('item')['rating'].count().clip(upper=100)

# Create trace
trace = go.Histogram(x = data.values,
                     name = 'Ratings',
                     xbins = dict(start = 0,
                                  end = 100,
                                  size = 2))
# Create layout
layout = go.Layout(title = 'Distribution Of Number of Ratings Per Item (Clipped at 100)',
                   xaxis = dict(title = 'Number of Ratings Per Item'),
                   yaxis = dict(title = 'Count'),
                   bargap = 0.2)

# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig) #후기가 20개 미만(x축)이 대다수임. 이것들은 다 잘라버리면 됨
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-67a1df4a8615> in <module>
#       3
#       4 # Create trace
# ----> 5 trace = go.Histogram(x = data.values,
#       6                      name = 'Ratings',
#       7                      xbins = dict(start = 0,
#
# NameError: name 'go' is not defined

# %%
# Number of ratings per item
data = df.groupby('user')['rating'].count().clip(upper=100)

# Create trace
trace = go.Histogram(x = data.values,
                     name = 'Ratings',
                     xbins = dict(start = 0,
                                  end = 100,
                                  size = 2))
# Create layout
layout = go.Layout(title = 'Distribution Of Number of Ratings Per User (Clipped at 100)',
                   xaxis = dict(title = 'Number of Ratings Per User'),
                   yaxis = dict(title = 'Count'),
                   bargap = 0.2)

# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div id="baac689b-6efc-424c-afd6-0ec6add75b96" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("baac689b-6efc-424c-afd6-0ec6add75b96")) {
# ...

# %%
users = list(df['user'].value_counts()[lambda x:x>15].index) #15이상인 user만
products = list(df['item'].value_counts()[lambda x:x>20].index) #20이상인 product만

# %%
new_df = df[(df['user'].isin(users)) & df['item'].isin(products)]

# %%
new_df.head()
# Out:
#        user  item  rating
# 31   715142   142       3
# 46  1045856   142       5
# 47  1137569   142       4
# 54   730493   142       2
# 71   709291   142       3

# %%
new_df.shape #그럼 데이터가 많이 줄었다!
# Out:
# (29856, 3)

# %%
from sklearn.model_selection import train_test_split

import pandas as pd

from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise import SVD
from surprise.model_selection import cross_validate, KFold
from surprise.model_selection import GridSearchCV

# %%
reader = Reader()

data = Dataset.load_from_df(new_df[['user', 'item', 'rating']], reader) #순서주의, 그리고 data는 df가아님.surprise패키지사용한거라서

trainset = data.build_full_trainset()

testset = trainset.build_anti_testset()

# %%
#데이터차원축소-SVD이용. RMSE가장적은걸로
param_grid = {'n_epochs': [5, 10], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}

gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(data)

# best RMSE score?
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score?
print(gs.best_params['rmse'])
# Out:
# 0.9784860402800577
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
algo = gs.best_estimator['rmse'] 

predictions = algo.fit(trainset).test(testset) #test set을 넣어서 예측한값.

# %%
print(list(predictions[0:10]))
# Out:
# [Prediction(uid=715142, iid=7077, r_ui=3.5644761521972135, est=3.8486729891995557, details={'was_impossible': False}), Prediction(uid=715142, iid=93639, r_ui=3.5644761521972135, est=3.812256503854491, details={'was_impossible': False}), Prediction(uid=715142, iid=94288, r_ui=3.5644761521972135, est=4.042887535721242, details={'was_impossible': False}), Prediction(uid=715142, iid=1097, r_ui=3.5644761521972135, est=3.589877205741217, details={'was_impossible': False}), Prediction(uid=715142, iid=90906, r_ui=3.5644761521972135, est=4.2620174281337215, details={'was_impossible': False}), Prediction(uid=715142, iid=90909, r_ui=3.5644761521972135, est=4.338727889274572, details={'was_impossible': False}), Prediction(uid=715142, iid=90912, r_ui=3.5644761521972135, est=4.325262312669076, details={'was_impossible': False}), Prediction(uid=715142, iid=1032, r_ui=3.5644761521972135, est=3.8846987856737334, details={'was_impossible': False}), Prediction(uid=715142, iid=76160, r_ui=3.564476152197
# ...

# %%
#uid=user, iid=item, r_ui=true_value(???), est=estimated_value, details=details
prediction_df = pd.DataFrame(predictions, columns=['user', 'item', 'true_value', 'estimated_value', 'details'])

# %%
prediction_df.head()
# Out:
#      user   item  true_value  estimated_value                    details
# 0  715142   7077    3.564476         3.848673  {'was_impossible': False}
# 1  715142  93639    3.564476         3.812257  {'was_impossible': False}
# 2  715142  94288    3.564476         4.042888  {'was_impossible': False}
# 3  715142   1097    3.564476         3.589877  {'was_impossible': False}
# 4  715142  90906    3.564476         4.262017  {'was_impossible': False}

# %%
prediction_df['error'] = abs(prediction_df.estimated_value - prediction_df.true_value)
prediction_df = prediction_df.drop(['details'], 1)

# %%
con = sqlite3.connect("C:\\predictionDB.db")
prediction_df.to_sql('prediction', con, if_exists='replace', chunksize=1000)

# %%
from collections import defaultdict

def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

get_top_n(predictions, 5)
# Out:
# defaultdict(list,
#             {715142: [(6974, 4.406041058477778),
#               (63601, 4.3869078833946835),
#               (90957, 4.351101260106994),
#               (90909, 4.351018098106018),
#               (91349, 4.347430389333036)],
#              1045856: [(90957, 4.373066552577323),
#               (90907, 4.356451661052359),
#               (6955, 4.300108872981455),
#               (92530, 4.285125765758153),
#               (6974, 4.270769793243073)],
#              1137569: [(90957, 4.402186223458482),
#               (6974, 4.366081674719808),
#               (6955, 4.354911214058018),
#               (63601, 4.321896635435527),
#               (90910, 4.303347790748586)],
#              730493: [(6955, 3.879180974192229),
#               (6974, 3.856272004071514),
#               (63601, 3.830930675748349),
#               (90910, 3.83061483530449),
#               (90957, 3.796831631437102)],
#              709291: [(90957, 4.233204088018341),
# ...
